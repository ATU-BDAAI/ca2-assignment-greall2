# %% [markdown]
#  *Artificial Intelligence for Vision & NLP* &nbsp; | &nbsp;  *ATU Donegal - Postgrad Diploma in Big Data Analytics & Artificial Intelligence*
#
# # Student Submisison
# Name           : Ríona Greally                <br>
# Student Number : L00196662         <br>
# Due Date       : 12th May 2026                <br>
# Assignment     : CA2             <br>
# Module         : AI for Vision and NLP    <br>
# Course         : Postgraduate Diploma in Big Data Analytics and AI

# %% [markdown]
# ## NLP and Vision Pipeline : High Level
# An image of your working pipeline at high level can be inserted here

# %% [markdown]
# # Initialisation
# Perform pip installs(or use a requirements.txt) <br>
# perform imports

# %% [markdown]
# ## Install packages

# %%
# pip installs
pip install pymupdf
pip install opencv-python
pip install matplotlib
pip install numpy panda
pip install nltk
pip install scikit-learn
pip install spacy
python -m spacy download en_core_web_sm
# Out:
#   Cell In[25], line 2
#     pip install pymupdf
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Imports

# %%
# imports
import sys
print(sys.executable)
import pymupdf
import os
import site
print(site.getusersitepackages())
import cv2
import matplotlib.pyplot as plt
# allows inline plotting
# %matplotlib inline

import pytesseract
from pytesseract import Output
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

import spacy
nlp = spacy.load("en_core_web_sm")


import nltk
nltk.download('punkt_tab')

from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize

import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# regular expression
import re
# Out:
# C:\Users\rgreally\AppData\Local\anaconda3\python.exe
# C:\Users\rgreally\AppData\Roaming\Python\Python313\site-packages
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\rgreally\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rgreally\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\rgreally\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# # Support Functions

# %%
plt.rcParams['figure.figsize'] = (20, 20)
custom_config = r'--oem 3 --psm 6'

# %% [markdown]
# # OCR

# %%
#opening PDF for processing
doc = pymupdf.open("setup_tesseract_OCR.pdf")

#saving mulitple pages from the pdf doc as images
for page_num, page in enumerate(doc):
    pix = page.get_pixmap(dpi=200)
    pix.save(f"TextCleansing_page_{page_num + 1}.jpg")

# store all extracted text
all_text = ""

#looping through eaaach image saved from the pdf
for page_num in range(len(doc)):
    img = cv2.imread(f"TextCleansing_page_{page_num + 1}.jpg")
    print(f"Page {page_num + 1} shape:", img.shape)
    
    #Converting image to String
    st = pytesseract.image_to_string(img, config=custom_config)
  
    print(f"\n--- Page {page_num + 1} Text ---\n")
    print(st)  # show first 300 characters of each page 

    #appending extracted text from current page to text from the full doc
    all_text += st
# Out:
# Page 1 shape: (2200, 1700, 3)
#
# --- Page 1 Text ---
#
# et ie il Soha Letterkenny Campu: Killybegs Campu:
# Tesseract OCR Set up
# Pre-requisites:
# e Anaconda Navigator installed and set up
# e Jupyter notebook working
# e Windows platform
# Tesseract OCR Setup Guide (Windows + Conda + Jupyter + requirements.txt)
# e Create a Conda environment
# e Install all Python OCR libraries from a requirements.txt file
# e Install Tesseract OCR (Windows)
# e Configure Jupyter Notebook to use Tesseract
# e Runa working OCR test
# This guide works on restricted laptops.
# Note some important clarification about Tesseract:
# e Tesseract is an OCR engine — a program that can read text from images
# e It is free and open source and maintained by Google
# e It is not a Python package
# e = It is not a machine-learning library
# e It is not installed with pip install pytesseract (this is a python wrapper library)
# e It does not depend on NumPy or OpenCV(these libraries are used before OCR to load or
# preprocess images)
# Tesseract is an Optical Character Recognition (OCR) library for Python, which can be used to read and
# recognise text in images, e.g. of pages, license plates, etc. To use it, we begin by importing the
# required modules.
# There are different versions available, where the latest is v5. Tesseract v5 - the modern LSTM-based
# (LSTM - Long Short-Term Memory, a type of deep learning network) version, which is a neural network
# engine making it faster and more accurate than older tesseract versions
# [Version [Year | OCREngine _| Accuracy | SpeedKey | Features
# release
# small updates
# hOCR, more
# languages
# big accuracy jump
# best models
# Al for Vision and NLP
#
# Page 2 shape: (2200, 1700, 3)
#
# --- Page 2 Text ---
#
# - ;
# i. !
# f ye
# Steps
# 1. In your labs folder create a requirements.txt file named : requirements.txt
# Add the following contents :
# pytesseract
# opencv-python
# pillow
# numpy
# matplotlib
# easyocr
# ipykernel
# pymupdf
# (You can add more libraries later if needed.)
# 2. Create and activate a Conda environment: Open Anaconda Prompt:
# Url Maclilss pS ae | SA
# (base) C:\Windows\System32>|
# Type:
# conda create -n ocr_env python=3.10
# conda activate ocr_env
# 3. Change directory to where the lab and requirements.txt are located
# cd <path_name>
# Example:
# Cocr_env) C:\Windows\System32>cd ../..
# (ocr_env) C:\>cd Users\Helena.Gibson
# (ocr_env) C:\Users\Helena.Gibson>|
# 4. Install everything from the requirements.txt: Type
# pip install -r requirements.txt
# 5. Add the conda environment to Jupyter: This adds a kernel that can be selected in your Jupyter
# notebook. Type
# python -m ipykernel install --user --name ocr_env --display-name
# "Python (ocr_env)"
# 6. Install Tesseract OCR for Windows
# Download the official Windows installer file from https://digi.bib.uni-mannheim.de/tesseract/ or
# (also added BB for convenience)
# tesseract-ocr-w64-setup-5.5.0.exe (64-bit)
# Al for Vision and NLP
#
# Page 3 shape: (2200, 1700, 3)
#
# --- Page 3 Text ---
#
# Ollscoil Letterkenny Campus Killybegs Campus
# Teicneolaiochta 1 f 1
# an Atlantaigh unt ;
# : Irelan
# Atlantic ) 18 660C
# GX Technological .
# SAA vniversity atuie
# 9) tesseract-ocr-w64-setup-5.5.0.20241111.exe
# Double click the installer exe file to install the full tesseract application
# If admin rights are available, install to:
# C:\Program Files\Tesseract-OCR\
# If admin rights are not available, choose a folder inside the user profile (this works and avoids
# permission issues) e.g.:
# C:\Users\<yourname>\Tesseract-OCR\
# Students must know the full path to tesseract.exe, as this will be added to the python notebook.
# Example: C:\Users\Helena.Gibson\tesseract\tesseract
# 7. \n your Jupyter notebook import the python wrapper(pytesseract) and set the location of
# tesseract application. Jupyter does NOT automatically detect Tesseract.
# pytesseract.pytesseract.tesseract_cmd =
# r"C: \Users\<yourname>\Tesseract-OCR\tesseract.exe"
# Example:
# import pytesseract
# from pytesseract import Output
# # change this path name to where you have stored tesseract.exe
# pytesseract.pytesseract.tesseract_cmd = r"C:\Users\Helena.Gibson\tesseract\tesseract\tesseract.exe”
# 8. In the Jupyter Notebook the kernel can now be selected to the one just created — ocr_env
# S jupyter Lab_Tesseract_OCR Last Checkpoint: 1 hour ago a
# File Edit View Run Kernel Settings Help sted
# @+X 6 © >» #& C » Markdown v Jupytertab (7 f& ocr_env O B
# Artificial Intelligence for Vision & NLP | ATU Donegal - Post Grad Diploma in Big DataXigalytics & 8
# Y Artificial Intelligence
# a
# Select Kernel
# Select kernel for: "Lab_Tesseract_OCR.ipynb"
# Start Preferred Kernel
# (ete me
# Pred Anal Labs Kernel
# It Python 3 (ipykernel)
# ust Use No Kernel
# fue No Kernel
# ae Use Kernel from Preferred Session
# Lab_Tesseract_OCR.ipynb
# 006 —Lab2d_EasyOCR .ipynb
# ata Lab2d_Tesseract.ipynb
# Use Kernel from Other Session
# 9. The tesseract lab python notebook should now execute successfully.
# Al for Vision and NLP

# %% [markdown]
# # NLP

# %% [markdown]
# ## Tokenisation

# %%
#applying nlp to the full extraxted text from document
nlp_allTxt = nlp(all_text)

#looping through fist 20 tokend from the doc and printing them
for token in nlp_allTxt[:20]:
    print(token.text)
# Out:
# et
# ie
# il
# Soha
# Letterkenny
# Campu
# :
# Killybegs
# Campu
# :
#
#
# Tesseract
# OCR
# Set
# up
#
#
# Pre
# -
# requisites
# :

# %%
#Total number of tokens in the document
len(nlp_allTxt)
# Out:
# 935

# %% [markdown]
# ## Stop Words

# %%
#loading english stopwords from NLTK
stop_words = set(stopwords.words('english'))

#converting tokens to lowercase and excluding words that add no meaning 
tokens_without_sw = [token.text for token in nlp_allTxt if token.text.lower() not in stop_words]

#Total of number from document after stopwords removed
len(tokens_without_sw)
# Out:
# 758

# %% [markdown]
# ## Lemmatisation

# %%
#Printing first 50 Tokens along with their lemma, POS tag, and description tags
for token in nlp_allTxt[:50]:
    print(f"{token.text:{20}} {token.lemma_:{20}} {token.pos_:{10}} {token.tag_:{5}} {spacy.explain(token.tag_)}")


lemmatised_tokens = [token.lemma_ for token in nlp_allTxt if not token.is_stop and token.is_alpha]
# Out:
# et                   et                   PROPN      NNP   noun, proper singular
# ie                   ie                   X          FW    foreign word
# il                   il                   PROPN      NNP   noun, proper singular
# Soha                 Soha                 PROPN      NNP   noun, proper singular
# Letterkenny          Letterkenny          PROPN      NNP   noun, proper singular
# Campu                Campu                PROPN      NNP   noun, proper singular
# :                    :                    PUNCT      :     punctuation mark, colon or ellipsis
# Killybegs            Killybegs            PROPN      NNP   noun, proper singular
# Campu                Campu                PROPN      NNP   noun, proper singular
# :                    :                    PUNCT      :     punctuation mark, colon or ellipsis
#
#
#                     SPACE      _SP   whitespace
# Tesseract            Tesseract            PROPN      NNP   noun, proper singular
# OCR                  OCR                  PROPN      NNP   noun, proper singular
# Set                  Set                  VERB       VBD   verb, past tense
# up                   up                   ADP        RP    adverb, particle
#
#
#                     SPACE      _SP   whitespace
# Pre                  Pre                  NOUN       NNS   noun, plural
# -                    -                    NOUN       NNS   noun, plural
# requisites           requisite            NOUN       NNS   noun, plural
# :                    :                    PUNCT      :     punctuation mark, colon or ellipsis
#
#
#                     SPACE      _SP   whitespace
# e                    e                    NOUN       NN    noun, singular or mass
# Anaconda             Anaconda             PROPN      NNP   noun, proper singular
# Navigator            Navigator            PROPN      NNP   noun, proper singular
# installed            instal               VERB       VBD   verb, past tense
# and                  and                  CCONJ      CC    conjunction, coordinating
# set                  set                  VERB       VBD   verb, past tense
# up                   up                   ADP        RP    adverb, particle
#
#
#                     SPACE      _SP   whitespace
# e                    e                    NOUN       NN    noun, singular or mass
# Jupyter              Jupyter              PROPN      NNP   noun, proper singular
# notebook             notebook             NOUN       NN    noun, singular or mass
# working              work                 VERB       VBG   verb, gerund or present participle
#
#
#                     SPACE      _SP   whitespace
# e                    e                    NOUN       NN    noun, singular or mass
# Windows              Windows              PROPN      NNP   noun, proper singular
# platform             platform             NOUN       NN    noun, singular or mass
#
#
#                     SPACE      _SP   whitespace
# Tesseract            Tesseract            PROPN      NNP   noun, proper singular
# OCR                  OCR                  PROPN      NNP   noun, proper singular
# Setup                Setup                PROPN      NNP   noun, proper singular
# Guide                Guide                PROPN      NNP   noun, proper singular
# (                    (                    PUNCT      -LRB- left round bracket
# Windows              Windows              PROPN      NNP   noun, proper singular
# +                    +                    CCONJ      CC    conjunction, coordinating
# Conda                Conda                PROPN      NNP   noun, proper singular
# +                    +                    CCONJ      CC    conjunction, coordinating
# Jupyter              jupyter              NOUN       NN    noun, singular or mass
# +                    +                    NUM        CD    cardinal number
# requirements.txt     requirements.txt     X          ADD   email

# %% [markdown]
# ## TF-IDR

# %%
#convert cleaned lemmatised tokens back into a single text string to use for TF-IDF
clean_text = " ".join(lemmatised_tokens)

#Create an instance of the TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()

#applying TF-IDF to the cleaned text
tfidf_matrix = tfidf_vectorizer.fit_transform([clean_text])

#SAving the important words as features
features = tfidf_vectorizer.get_feature_names_out()

#Convert TF-IDF matrix into scores
tfidf_scores = tfidf_matrix.toarray()[0]

# Create Dataframe to store words and their importance scores
df_tfidf = pd.DataFrame({
    "Word": features,
    "Score": tfidf_scores
})

# Sort words by highest importance
df_sorted = df_tfidf.sort_values(by="Score", ascending=False)

df_sorted.head(10)
# Out:
#           Word     Score
# 189  tesseract  0.372572
# 157     python  0.292735
# 91      kernel  0.292735
# 89     jupyter  0.239511
# 129        ocr  0.239511
# 82     install  0.239511
# 127   notebook  0.186286
# 3          add  0.159674
# 34       conda  0.159674
# 103    library  0.159674

# %% [markdown]
# # Vision

# %% [markdown]
# ## Sub Heading 1

# %%
# code here...

# %% [markdown]
# # Multi-modal

# %% [markdown]
# ## Sub Heading 1

# %%
# code here

# %% [markdown]
# # Final Output

# %%
# code
